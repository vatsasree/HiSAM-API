# %%
import os
import pickle

def load_pickle(path):
    with open(path, 'rb') as f:
        data = pickle.load(f)
    return data

data = load_pickle('data_dict.pkl')

# %%
data
# Out:
# {UUID('4b6971c7-d635-4095-9eaf-94775aba7870'): 'Success',
#  UUID('df5dcf65-9426-4431-961c-23f3d445f8c9'): 'Success'}

# %%
import uuid

u = uuid.uuid4()
u, str(u)
# Out:
# (UUID('8175b68b-4ae9-408b-80da-b97a6b6b8879'),
#  '8175b68b-4ae9-408b-80da-b97a6b6b8879')

# %%
def save_pickle(data, path):
    with open(path, 'wb') as f:
        pickle.dump(data, f)

token_data = ['D18b61076117b2a02df33dfd15849d58434bee6e5912506d4a37e4b1a65e0eca']
save_pickle(token_data, 'token_db.pkl')
